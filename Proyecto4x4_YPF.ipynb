# %% [markdown]
# <a href="https://colab.research.google.com/github/antonellafontanetto/Pre-Entrega-2-Data-Science/blob/main/Proyecto4x4_YPF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Proyecto 4x4 YPF: Primer Pilar Vaca Muerta a corto plazo
#
# El siguiente proyecto está focalizado en predecir el comportamiento de determinadas variables en el marco del proyecto 4x4 de YPF, el cual consta de cuadriplicar la empresa en los próximos 4 años a través de la expansión de la producción, eficiencia en los procesos y mayor foco en la generación de valor.
#
# Para lo cual el proyecta va a constar del siguiente procedimiento:
#
# 1) Recolección de Datos
#
# 2) Exploración y Procesamiento de los datos (exploración de los datos, discreción de variables, normalización, limpieza, visualización previa)
#
# 3) Modelado (construir y testear modelos para predecir o clasificar información o encontrar patrones de datos)
#
# 4) Puesta en Producción (predecir nuevos datos, comunicar los resultados, integrar los resultados con aplicación)

# %% [markdown]
# # Recolección de datos
#
# Importo todas las libreras necesarias para la recolección de datos y el análisis exploratorio.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
produccion = pd.read_csv('/content/produccion.zip', usecols=['anio','empresa','tipopozo','tipoestado','prod_gas','prod_pet','profundidad','areayacimiento','cuenca','provincia','tipo_de_recurso','sub_tipo_recurso','prod_agua','tipoextraccion','profundidad','areapermisoconcesion','coordenadax','coordenaday','proyecto','clasificacion','subclasificacion'])
produccion
# Out:
#         anio   prod_pet    prod_gas  prod_agua     tipoextraccion  \
# 0       2018   0.000000  171.937000   0.000000  Surgencia Natural
# 1       2017   0.000000  245.850000  16.680000       Plunger Lift
# 2       2018   0.000000  514.696000  17.000000  Surgencia Natural
# 3       2015   0.000000  422.110000   0.000000    Bombeo Mecánico
# 4       2018   0.000000  217.103000   7.300000  Surgencia Natural
# ...      ...        ...         ...        ...                ...
# 345377  2024  14.049906   17.378994  72.385001    Bombeo Mecánico
# 345378  2023   0.000000    0.000000   0.000000                NaN
# 345379  2024  60.960855  602.844409  63.852351  Surgencia Natural
# 345380  2024   0.000000    0.000000   0.000000  Surgencia Natural
# 345381  2024   0.000000    0.000000   0.000000  Surgencia Natural
#
#                      tipoestado     tipopozo  \
# 0           Extracción Efectiva     Gasífero
# 1           Extracción Efectiva     Gasífero
# 2           Extracción Efectiva     Gasífero
# 3           Extracción Efectiva     Gasífero
# 4           Extracción Efectiva     Gasífero
# ...                         ...          ...
# 345377      Extracción Efectiva  Petrolífero
# 345378                      NaN          NaN
# 345379      Extracción Efectiva  Petrolífero
# 345380  Parado Transitoriamente     Gasífero
# 345381  Parado Transitoriamente  Petrolífero
#
#                                  empresa  profundidad    areapermisoconcesion  \
# 0          YSUR ENERGÍA ARGENTINA S.R.L.       3828.0  ESTACION FERNANDEZ ORO
# 1          YSUR ENERGÍA ARGENTINA S.R.L.       2338.4   ANTICLINAL CAMPAMENTO
# 2          YSUR ENERGÍA ARGENTINA S.R.L.       2707.0  ESTACION FERNANDEZ ORO
# 3          YSUR ENERGÍA ARGENTINA S.R.L.       3305.0   AL NORTE DE LA DORSAL
# 4          YSUR ENERGÍA ARGENTINA S.R.L.       2618.0   AL NORTE DE LA DORSAL
# ...                                  ...          ...                     ...
# 345377  Petrolera Aconcagua Energia S.A.       2585.0             ENTRE LOMAS
# 345378  Petrolera Aconcagua Energia S.A.       2848.0             ENTRE LOMAS
# 345379  Petrolera Aconcagua Energia S.A.       2840.0             ENTRE LOMAS
# 345380  Petrolera Aconcagua Energia S.A.       2400.0             ENTRE LOMAS
# 345381  Petrolera Aconcagua Energia S.A.       2858.0             ENTRE LOMAS
#
#                    areayacimiento    cuenca  provincia  coordenadax  \
# 0          ESTACION FERNANDEZ ORO  NEUQUINA  Rio Negro   -67.864960
# 1       ANTICLINAL CAMPAMENTO SUR  NEUQUINA    Neuquén   -69.733102
# 2          ESTACION FERNANDEZ ORO  NEUQUINA  Rio Negro   -67.837875
# 3                         GUANACO  NEUQUINA    Neuquén   -69.255971
# 4                         GUANACO  NEUQUINA    Neuquén   -69.231360
# ...                           ...       ...        ...          ...
# 345377                 EL CARACOL  NEUQUINA    Neuquén   -68.452390
# 345378                CHARCO BAYO  NEUQUINA  Rio Negro   -68.099940
# 345379                CHARCO BAYO  NEUQUINA  Rio Negro   -68.106619
# 345380                CHARCO BAYO  NEUQUINA  Rio Negro   -68.129670
# 345381                CHARCO BAYO  NEUQUINA  Rio Negro   -68.085408
#
#         coordenaday  tipo_de_recurso      proyecto clasificacion  \
# 0        -39.016722  NO CONVENCIONAL      GAS PLUS   EXPLOTACION
# 1        -39.024859  NO CONVENCIONAL      GAS PLUS   EXPLOTACION
# 2        -39.019313  NO CONVENCIONAL  Sin Proyecto   EXPLOTACION
# 3        -38.860779  NO CONVENCIONAL      GAS PLUS   EXPLOTACION
# 4        -38.869270  NO CONVENCIONAL      GAS PLUS   EXPLOTACION
# ...             ...              ...           ...           ...
# 345377   -37.954170  NO CONVENCIONAL  Sin Proyecto   EXPLOTACION
# 345378   -38.174340  NO CONVENCIONAL  Sin Proyecto   EXPLOTACION
# 345379   -38.178494  NO CONVENCIONAL  Sin Proyecto   EXPLOTACION
# 345380   -38.149710  NO CONVENCIONAL  Sin Proyecto   EXPLOTACION
# 345381   -38.211980  NO CONVENCIONAL  Sin Proyecto   EXPLORACION
#
#              subclasificacion sub_tipo_recurso
# 0                  DESARROLLO            TIGHT
# 1                  DESARROLLO            TIGHT
# 2                  DESARROLLO            TIGHT
# 3                  DESARROLLO            TIGHT
# 4                  DESARROLLO            TIGHT
# ...                       ...              ...
# 345377               AVANZADA            SHALE
# 345378             DESARROLLO            TIGHT
# 345379             DESARROLLO            TIGHT
# 345380             DESARROLLO            TIGHT
# 345381  EXPLORATORIO PROFUNDO            TIGHT
#
# [345382 rows x 20 columns]

# %%
#Filtro por cada dataset solo los registros para YPF S.A.
prod_ypf = produccion[(produccion['empresa'] == 'YPF S.A.')&(produccion['cuenca'] == 'NEUQUINA')&(produccion['anio']>2022)]

prod_ypf
# Out:
#         anio  prod_pet  prod_gas  prod_agua             tipoextraccion  \
# 8572    2025     32.29    172.10       0.00               Plunger Lift
# 8578    2025      0.00      0.00       0.00          Surgencia Natural
# 8584    2025      0.00      0.00       0.00            Bombeo Mecánico
NO CONVENCIONAL  Sin Proyecto   EXPLOTACION
#
#        subclasificacion sub_tipo_recurso
# 8572         DESARROLLO            TIGHT
# 8578         DESARROLLO            SHALE
# 8584         DESARROLLO            SHALE
# 8590         DESARROLLO            SHALE
# 8596         DESARROLLO            SHALE
# ...                 ...              ...
# 199438          CONTROL            SHALE
# 199440       DESARROLLO            SHALE
# 199442       DESARROLLO            SHALE
# 199446       DESARROLLO            SHALE
# 199448       DESARROLLO            SHALE
#
# [56418 rows x 20 columns]

# %%
#Con rename se logró renombrar las columnas que tenían nombres abreviados o poco legibles
prod_ypf=prod_ypf.rename(columns={'anio':'Año','prod_pet':'Produccion de Petroleo','prod_gas':'Produccion de Gas','prod_agua':'Produccion de agua','tipoextraccion':'Tipo de extraccion','tipoestado':'Tipo de estado','tipopozo':'Tipo de pozo','empresa':'Empresa','profundidad':'Profundidad','areapermisoconcesion':'Area de permiso de concesion','cuenca':'Cuenca','provincia':'Provincia','tipo_de_recurso':'Tipo de recurso','proyecto':'Proyecto','clasificacion':'Clasificacion','subclasificacion':'Subclasificacion','sub_tipo_recurso':'Subtipo de recurso'})
prod_ypf
# Out:
#          Año  Produccion de Petroleo  Produccion de Gas  Produccion de agua  \
# 8572    2025                   32.29             172.10                0.00
# 8578    2025                    0.00               0.00                0.00
# 8584    2025                    0.00               0.00                0.00
# 8590    2025                    0.00               0.00                0.00
# 8596    2025                   55.99               3.37                0.00
# ...      ...                     ...                ...                 ...
# 199438  2024                    0.00               0.00                0.00
# 199440  2024                 1642.63             101.18             1102.79
# 199442  2024                 2441.10             153.31             1287.65
# 199446  2024                    0.00               0.00                0.00
# 199448  2024                    0.00               0.00                0.00
#
#                Tipo de extraccion           Tipo de estado Tipo de pozo  \
# 8572                 Plunger Lift      Extracción Efectiva     Gasífero
# 8578            Surgencia Natural               Abandonado    Otro tipo
# 8584              Bombeo Mecánico               En Estudio    Otro tipo
# 8590            Surgencia Natural               Abandonado    Otro tipo
# 8596            Surgencia Natural      Extracción Efectiva  Petrolífero
# ...                           ...                      ...          ...
# 199438  Sin Sistema de Extracción    En Inyección Efectiva     Sumidero
# 199440          Surgencia Natural      Extracción Efectiva  Petrolífero
# 199442          Surgencia Natural      Extracción Efectiva  Petrolífero
# 199446          Surgencia Natural  Parado Transitoriamente     Gasífero
# 199448          Surgencia Natural  Parado Transitoriamente     Gasífero
#
#          Empresa  Profundidad Area de permiso de concesion  \
# 8572    YPF S.A.       3844.0       ESTACION FERNANDEZ ORO
# 8578    YPF S.A.       2827.0                   EL OREJANO
# 8584    YPF S.A.       2977.0              LA AMARGA CHICA
# 8590    YPF S.A.       4092.0                   EL OREJANO
# 8596    YPF S.A.       4945.0                 LOMA CAMPANA
# ...          ...          ...                          ...
# 199438  YPF S.A.       2046.0            AGUADA DEL CHAÑAR
# 199440  YPF S.A.       5889.0            AGUADA DEL CHAÑAR
# 199442  YPF S.A.          0.0            AGUADA DEL CHAÑAR
# 199446  YPF S.A.       4491.0                 LAS TACANAS
# 199448  YPF S.A.       4455.0                 LAS TACANAS
#
#                 areayacimiento    Cuenca  Provincia  coordenadax  coordenaday  \
# 8572    ESTACION FERNANDEZ ORO  NEUQUINA  Rio Negro   -67.810843   -39.024083
# 8578                EL OREJANO  NEUQUINA    Neuquén   -69.179098   -38.009987
# 8584           LA AMARGA CHICA  NEUQUINA    Neuquén   -68.748543   -38.176774
# 8590                EL OREJANO  NEUQUINA    Neuquén   -69.200359   -37.958765
# 8596              LOMA CAMPANA  NEUQUINA    Neuquén   -68.678007   -38.329983
# ...                        ...       ...        ...          ...          ...
# 199438           LOMA COLORADA  NEUQUINA    Neuquén   -68.525949   -38.122077
# 199440           LOMA COLORADA  NEUQUINA    Neuquén   -68.558082   -38.076855
# 199442           LOMA COLORADA  NEUQUINA    Neuquén   -68.558013   -38.076854
# 199446             LAS TACANAS  NEUQUINA    Neuquén   -69.335181   -38.710951
# 199448             LAS TACANAS  NEUQUINA    Neuquén   -69.335078   -38.710951
#
#         Tipo de recurso      Proyecto Clasificacion Subclasificacion  \
# 8572    NO CONVENCIONAL      GAS PLUS   EXPLOTACION       DESARROLLO
# 8578    NO CONVENCIONAL  Sin Proyecto   EXPLOTACION       DESARROLLO
# 8584    NO CONVENCIONAL  Sin Proyecto   EXPLOTACION       DESARROLLO
# 8590    NO CONVENCIONAL  Sin Proyecto   EXPLOTACION       DESARROLLO
# 8596    NO CONVENCIONAL  Sin Proyecto   EXPLOTACION       DESARROLLO
# ...                 ...           ...           ...              ...
# 199438  NO CONVENCIONAL  Sin Proyecto      SERVICIO          CONTROL
# 199440  NO CONVENCIONAL  Sin Proyecto   EXPLOTACION       DESARROLLO
# 199442  NO CONVENCIONAL  Sin Proyecto   EXPLOTACION       DESARROLLO
# 199446  NO CONVENCIONAL  Sin Proyecto   EXPLOTACION       DESARROLLO
# 199448  NO CONVENCIONAL  Sin Proyecto   EXPLOTACION       DESARROLLO
#
#        Subtipo de recurso
# 8572                TIGHT
# 8578                SHALE
# 8584                SHALE
# 8590                SHALE
# 8596                SHALE
# ...                   ...
# 199438              SHALE
# 199440              SHALE
# 199442              SHALE
# 199446              SHALE
# 199448              SHALE
#
# [56418 rows x 20 columns]

# %%
#Vamos a ver que tipo de estructura tiene prod_ypf
type(prod_ypf)
# Out:
# pandas.core.frame.DataFrame

# %%
#Con la función shape podemos ver cuantas features y registros contiene el dataframe prod_ypf
prod_ypf.shape
# Out:
# (56418, 20)

# %%
#Con la función columns puedo visualizar los nombres de los features
prod_ypf.columns
# Out:
# Index(['Año', 'Produccion de Petroleo', 'Produccion de Gas',
#        'Produccion de agua', 'Tipo de extraccion', 'Tipo de estado',
#        'Tipo de pozo', 'Empresa', 'Profundidad',
#        'Area de permiso de concesion', 'areayacimiento', 'Cuenca', 'Provincia',
#        'coordenadax', 'coordenaday', 'Tipo de recurso', 'Proyecto',
#        'Clasificacion', 'Subclasificacion', 'Subtipo de recurso'],
#       dtype='object')

# %%
#A través de la función head() puedo visualizar los primeros 5 registros
prod_ypf.head()
# Out:
#        Año  Produccion de Petroleo  Produccion de Gas  Produccion de agua  \
# 8572  2025                   32.29             172.10                 0.0
# 8578  2025                    0.00               0.00                 0.0
# 8584  2025                    0.00               0.00                 0.0
# 8590  2025                    0.00               0.00                 0.0
# 8596  2025                   55.99               3.37                 0.0
#
#      Tipo de extraccion       Tipo de estado Tipo de pozo   Empresa  \
# 8572       Plunger Lift  Extracción Efectiva     Gasífero  YPF S.A.
# 8578  Surgencia Natural           Abandonado    Otro tipo  YPF S.A.
# 8584    Bombeo Mecánico           En Estudio    Otro tipo  YPF S.A.
# 8590  Surgencia Natural           Abandonado    Otro tipo  YPF S.A.
# 8596  Surgencia Natural  Extracción Efectiva  Petrolífero  YPF S.A.
#
#       Profundidad Area de permiso de concesion          areayacimiento  \
# 8572       3844.0       ESTACION FERNANDEZ ORO  ESTACION FERNANDEZ ORO
# 8578       2827.0                   EL OREJANO              EL OREJANO
# 8584       2977.0              LA AMARGA CHICA         LA AMARGA CHICA
# 8590       4092.0                   EL OREJANO              EL OREJANO
# 8596       4945.0                 LOMA CAMPANA            LOMA CAMPANA
#
#         Cuenca  Provincia  coordenadax  coordenaday  Tipo de recurso  \
# 8572  NEUQUINA  Rio Negro   -67.810843   -39.024083  NO CONVENCIONAL
# 8578  NEUQUINA    Neuquén   -69.179098   -38.009987  NO CONVENCIONAL
# 8584  NEUQUINA    Neuquén   -68.748543   -38.176774  NO CONVENCIONAL
# 8590  NEUQUINA    Neuquén   -69.200359   -37.958765  NO CONVENCIONAL
# 8596  NEUQUINA    Neuquén   -68.678007   -38.329983  NO CONVENCIONAL
#
#           Proyecto Clasificacion Subclasificacion Subtipo de recurso
# 8572      GAS PLUS   EXPLOTACION       DESARROLLO              TIGHT
# 8578  Sin Proyecto   EXPLOTACION       DESARROLLO              SHALE
# 8584  Sin Proyecto   EXPLOTACION       DESARROLLO              SHALE
# 8590  Sin Proyecto   EXPLOTACION       DESARROLLO              SHALE
# 8596  Sin Proyecto   EXPLOTACION       DESARROLLO              SHALE

# %%
# Mientras que con la función tail(15) puedo visualizar los últimos 15 registros del dataframe
prod_ypf.tail(15)
# Out:
#          Año  Produccion de Petroleo  Produccion de Gas  Produccion de agua  \
# 199418  2024                 3409.13             645.07             1584.58
# 199420  2024                    5.33               4.13              569.26
# 199422  2024                  570.73             166.81             1241.24
# 199424  2024                 1523.42             445.38             2753.77
# 199426  2024                 3054.73             987.58             2708.32
# 199428  2024                 2967.65             980.35             2439.32
# 199430  2024                 1775.53             542.29             2729.50
# 199432  2024                    5.03               1.04              403.62
# 199434  2024                 3904.39             203.65              867.70
# 199436  2024                 2543.15             168.20              950.83
# 199438  2024                    0.00               0.00                0.00
# 199440  2024                 1642.63             101.18             1102.79
# 199442  2024                 2441.10             153.31             1287.65
# 199446  2024                    0.00               0.00                0.00
# 199448  2024                    0.00               0.00                0.00
#
#                Tipo de extraccion           Tipo de estado Tipo de pozo  \
# 199418          Surgencia Natural      Extracción Efectiva  Petrolífero
# 199420          Surgencia Natural      Extracción Efectiva  Petrolífero
# 199422          Surgencia Natural      Extracción Efectiva  Petrolífero
# 199424          Surgencia Natural      Extracción Efectiva  Petrolífero
# 199426          Surgencia Natural      Extracción Efectiva  Petrolífero
# 199428          Surgencia Natural      Extracción Efectiva  Petrolífero
# 199430          Surgencia Natural      Extracción Efectiva  Petrolífero
# 199432          Surgencia Natural      Extracción Efectiva  Petrolífero
# 199434          Surgencia Natural      Extracción Efectiva  Petrolífero
# 199436          Surgencia Natural      Extracción Efectiva  Petrolífero
# 199438  Sin Sistema de Extracción    En Inyección Efectiva     Sumidero
# 199440          Surgencia Natural      Extracción Efectiva  Petrolífero
# 
Sin Proyecto   EXPLOTACION       DESARROLLO              SHALE
# 199448  Sin Proyecto   EXPLOTACION       DESARROLLO              SHALE

# %%
# Con dtypes podemos visualizar los tipos de datos que contiene cada feature (enteros, flotantes y objetos)
prod_ypf.dtypes
# Out:
# Año                               int64
# Produccion de Petroleo          float64
# Produccion de Gas               float64
# Produccion de agua              float64
# Tipo de extraccion               object
# Tipo de estado                   object
# Tipo de pozo                     object
# Empresa                          object
# Profundidad                     float64
# Area de permiso de concesion     object
# areayacimiento                   object
# Cuenca                           object
# Provincia                        object
# coordenadax                     float64
# coordenaday                     float64
# Tipo de recurso                  object
# Proyecto                         object
# Clasificacion                    object
# Subclasificacion                 object
# Subtipo de recurso               object
# dtype: object

# %%
# Ahora nos interesa ver cuantos son los datos faltantes por cada feature, en este caso no tenemos datos Nan
datosfaltantes = prod_ypf.isnull().sum()
print (datosfaltantes)
# Out:
# Año                             0
# Produccion de Petroleo          0
# Produccion de Gas               0
# Produccion de agua              0
# Tipo de extraccion              0
# Tipo de estado                  0
# Tipo de pozo                    0
# Empresa                         0
# Profundidad                     0
# Area de permiso de concesion    0
# areayacimiento                  0
# Cuenca                          0
# Provincia                       0
# coordenadax                     0
# coordenaday                     0
# Tipo de recurso                 0
# Proyecto                        0
# Clasificacion                   0
# Subclasificacion                0
# Subtipo de recurso              0
# dtype: int64

# %%
#Con la función describe puedo obtener todo lo relacionado a la estadística descriptiva (media, desvio estandar, mínimo, máximo, etc)
prod_ypf.describe()
# Out:
#                 Año  Produccion de Petroleo  Produccion de Gas  \
# count  56418.000000            56418.000000       56418.000000
# mean    2023.694601              475.228559         341.947332
# std        0.666078             1087.901163        1033.316212
# min     2023.000000                0.000000           0.000000
# 25%     2023.000000                0.000000           1.730000
# 50%     2024.000000               13.740000          60.815000
# 75%     2024.000000              344.087500         237.355000
# max     2025.000000            10489.260000       17143.070000
#
#        Produccion de agua    Profundidad   coordenadax   coordenaday
# count        56418.000000   56418.000000  56418.000000  56418.000000
# mean           187.986783    4111.578969    -68.747648    -38.448878
# std            577.349776    8018.702345      0.393260      0.307162
# min              0.000000       0.000000    -69.690352    -39.030925
# 25%              0.000000    3042.000000    -68.929286    -38.713258
# 50%              6.160000    3838.000000    -68.749217    -38.354928
# 75%             78.795000    5145.000000    -68.609166    -38.304814
# max          24615.830000  378939.000000    -67.679160    -36.206000

# %%
prod_ypf_2023=prod_ypf[prod_ypf['Año']==2023]
prod_ypf_2023
media_2023=prod_ypf_2023['Produccion de Petroleo'].mean()
media_2023
# Out:
# np.float64(445.29436681957833)

# %%
prod_ypf_2024=prod_ypf[prod_ypf['Año']==2024]
prod_ypf_2024
media_2024=prod_ypf_2024['Produccion de Petroleo'].mean()
media_2024
# Out:
# np.float64(487.16603230498356)

# %%
prod_ypf_2025=prod_ypf[prod_ypf['Año']==2025]
prod_ypf_2025
media_2025=prod_ypf_2025['Produccion de Petroleo'].mean()
media_2025
# Out:
# np.float64(536.3812050222018)
